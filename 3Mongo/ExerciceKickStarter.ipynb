# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %% [markdown]
# #### Pourquoi convertir object en string ?
#
# 1. Clarifier le type des données :
#
#     En pandas, une colonne de type object peut contenir divers types de données, comme des chaînes de caractères, des nombres mélangés avec du texte, ou même des valeurs None.
#     Pour MongoDB, les valeurs doivent avoir des types clairs et cohérents, car le format BSON exige des types bien définis (string, int, double, boolean, etc.).
#
# 2. Faciliter l’insertion dans MongoDB :
#
#     MongoDB traite correctement les chaînes de caractères (string), mais une colonne de type object pourrait provoquer des erreurs si elle contient des types mixtes ou incompatibles.
#
# 3. Éviter des comportements inattendus :
#
#     Si des valeurs non compatibles sont insérées dans MongoDB (par exemple, une valeur numérique ou un objet complexe non attendu dans une colonne de texte), cela pourrait entraîner des incohérences dans vos données.
#
# 4. Nettoyage des données :
#
#     Cette conversion est également une étape de nettoyage des données, qui vous permet de vérifier si les valeurs de vos colonnes sont bien ce que vous attendez avant de les insérer.

# %% [markdown]
# #### Pourquoi convertir en dictionnaire ?
#
# Dans MongoDB, les données sont stockées sous forme de documents BSON (Binary JSON). Lorsque vous utilisez un DataFrame pandas, les données sont structurées en lignes et colonnes, ce qui n'est pas directement compatible avec MongoDB.
#
# La conversion en dictionnaire est nécessaire car :
#
#     Format attendu par pymongo :
#         pymongo attend que les données soient sous forme de dictionnaires Python pour les insérer dans MongoDB. Chaque ligne d'un DataFrame devient un dictionnaire, où les clés correspondent aux noms des colonnes et les valeurs aux données.
#
#     Correspondance avec BSON :
#         MongoDB stocke les documents sous forme de BSON, un format directement mappé aux dictionnaires Python. Cela rend la conversion intuitive et naturelle.
#
# #### Pourquoi ne pas insérer directement le DataFrame ?
#
# MongoDB ne comprend pas directement les DataFrames pandas. Voici les problèmes principaux :
#
#     Structure incompatible : Un DataFrame est une structure tabulaire alors que MongoDB utilise des documents JSON.
#     Types de données : MongoDB utilise des types BSON spécifiques qui ne correspondent pas toujours directement aux types pandas.

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient()
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head(10)
# Out:
# /var/folders/jq/5h45x39s35g2pjt_r9rnmwzr0000gn/T/ipykernel_7021/182781903.py:1: DtypeWarning: Columns (6,8,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
# 5  1771789139                                   Room For Growth!
# 6  1301627822          Build a mini Udemy with Laravel and Vuejs
# 7   881336601                                         Applitizer
# 8  1669374237  Help I Am Wolves fund their first album "ABCD"...
# 9   556821416        Eco  Bamboo Underwear funding....GOT WOOD ?
#
#          category main_category currency    deadline      goal  \
# 0            Rock         Music      USD  2011-09-16    2000.0
# 1         Fashion       Fashion      USD  2012-08-22   18000.0
# 2  Tabletop Games         Games      USD  2016-07-19    2000.0
# 3       Art Books    Publishing      USD  2017-09-27   13000.0
# 4       Sculpture           Art      CAD  2016-02-24    5000.0
# 5         Couture       Fashion      USD  2016-05-02    2000.0
# 6             Web    Technology      CAD  2018-01-11    3000.0
# 7        Software    Technology      HKD  2017-08-20  100000.0
# 8           Music         Music      EUR  2017-12-04    1000.0
# 9         Fashion       Fashion      GBP  2012-12-13    9500.0
#
#               launched  pledged       state backers country  usd pledged  \
# 0  2011-08-17 06:31:31   1145.0    canceled      24      US       1145.0
# 1  2012-07-23 20:46:48   1851.0      failed      28      US       1851.0
# 2  2016-07-01 21:55:54   7534.0  successful     254      US       3796.0
# 3  2017-08-28 15:47:02  16298.0  successful     367      US       2670.0
# 4  2016-01-25 17:37:10      1.0      failed       1      CA     0.708148
# 5  2016-04-11 18:15:00      6.0      failed       2      US          6.0
# 6  2017-12-12 01:37:26    155.0        live       7      CA    15.563996
# 7  2017-07-21 16:50:05   1000.0      failed       1      HK    128.08538
# 8  2017-10-27 16:55:47   1465.0  successful      46      BE          0.0
# 9  2012-11-13 10:58:34   1212.0      failed      43      GB  1928.137119
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225
# 5          6.000000
# 6        123.811806
# 7        127.831467
# 8       1720.210418
# 9       1953.672808

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                150000 non-null  int64
#  1   name              149998 non-null  object
#  2   category          150000 non-null  object
#  3   main_category     150000 non-null  object
#  4   currency          150000 non-null  object
#  5   deadline          150000 non-null  object
#  6   goal              150000 non-null  object
#  7   launched          150000 non-null  object
#  8   pledged           150000 non-null  object
#  9   state             150000 non-null  object
#  10  backers           150000 non-null  object
#  11  country           150000 non-null  object
#  12  usd pledged       148518 non-null  object
#  13  usd_pledged_real  150000 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 16.0+ MB

# %%
# Clean data 

if df_ks.isna().any().any(): 
    print("Il y a des valeurs manquantes dans le tableau.")
else:
    print("Il n'y a pas de valeurs manquantes dans le tableau.")
    
df_ks_cleaned = df_ks.dropna()
print(f"Nombre de lignes avant nettoyage : {len(df_ks)}")
print(f"Nombre de lignes après nettoyage : {len(df_ks_cleaned)}")
print('\n')

df_ks_cleaned["name"] = df_ks_cleaned["name"].astype(str)
df_ks_cleaned["category"] = df_ks_cleaned["category"].astype(str)
df_ks_cleaned["main_category"] = df_ks_cleaned["main_category"].astype(str)
df_ks_cleaned["currency"] = df_ks_cleaned["currency"].astype(str)

#df_ks_cleaned.iloc[65465]
#df_ks_cleaned.iloc[65464]
invalid_indexes = df_ks_cleaned[df_ks_cleaned["deadline"] == "USD"].index
print("Lignes problématiques avant suppression :")
print(df_ks_cleaned.loc[invalid_indexes])
df_ks_cleaned = df_ks_cleaned.drop(index=invalid_indexes)

df_ks_cleaned["deadline"] = pd.to_datetime(df_ks_cleaned["deadline"])
df_ks_cleaned["goal"] = df_ks_cleaned["goal"].astype(float)
df_ks_cleaned["launched"] = pd.to_datetime(df_ks_cleaned["launched"])
df_ks_cleaned["pledged"] = df_ks_cleaned["pledged"].astype(float)
df_ks_cleaned["state"] = df_ks_cleaned["state"].astype(str)
df_ks_cleaned["backers"] = df_ks_cleaned["backers"].astype(int)
df_ks_cleaned["country"] = df_ks_cleaned["country"].astype(str)
df_ks_cleaned["usd pledged"] = df_ks_cleaned["usd pledged"].astype(float)

df_ks_cleaned = df_ks_cleaned.rename(columns={"usd pledged": "usd_pledged"})

print(df_ks_cleaned["name"].dtypes)
print(df_ks_cleaned["category"].dtypes)
print(df_ks_cleaned["main_category"].dtypes)
print(df_ks_cleaned["currency"].dtypes)
print(df_ks_cleaned["deadline"].dtypes)
print(df_ks_cleaned["goal"].dtypes)
print(df_ks_cleaned["launched"].dtypes)
print(df_ks_cleaned["pledged"].dtypes)
print(df_ks_cleaned["state"].dtypes)
print(df_ks_cleaned["backers"].dtypes)
print(df_ks_cleaned["country"].dtypes)
print(df_ks_cleaned["usd_pledged"].dtypes)
print(df_ks_cleaned["usd_pledged_real"].dtypes)
# Out:
# Il y a des valeurs manquantes dans le tableau.
# Nombre de lignes avant nettoyage : 150000
# Nombre de lignes après nettoyage : 148516
#
#
# Lignes problématiques avant suppression :
#              ID                            name          category  \
# 66141  85964225  Debut Album from Michael Adam   Grace is Leaving
#
#       main_category currency deadline        goal launched  \
# 66141    Indie Rock    Music      USD  2014-04-17    700.0
#
#                    pledged  state     backers country usd pledged  \
# 66141  2014-04-02 21:56:35  850.0  successful      32          US
#
#        usd_pledged_real
# 66141             850.0
# object
# object
# object
# object
# datetime64[ns]
# float64
# datetime64[ns]
# float64
# object
# int64
# object
# float64
# float64
# /var/folders/jq/5h45x39s35g2pjt_r9rnmwzr0000gn/T/ipykernel_7021/349359228.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ks_cleaned["name"] = df_ks_cleaned["name"].astype(str)
# /var/folders/jq/5h45x39s35g2pjt_r9rnmwzr0000gn/T/ipykernel_7021/349359228.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ks_cleaned["category"] = df_ks_cleaned["category"].astype(str)
# /var/folders/jq/5h45x39s35g2pjt_r9rnmwzr0000gn/T/ipykernel_7021/349359228.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ks_cleaned["main_category"] = df_ks_cleaned["main_category"].astype(str)
# /var/folders/jq/5h45x39s35g2pjt_r9rnmwzr0000gn/T/ipykernel_7021/349359228.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ks_cleaned["currency"] = df_ks_cleaned["currency"].astype(str)

# %%
df_ks_cleaned.head()
# Out:
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency   deadline     goal  \
# 0            Rock         Music      USD 2011-09-16   2000.0
# 1         Fashion       Fashion      USD 2012-08-22  18000.0
# 2  Tabletop Games         Games      USD 2016-07-19   2000.0
# 3       Art Books    Publishing      USD 2017-09-27  13000.0
# 4       Sculpture           Art      CAD 2016-02-24   5000.0
#
#              launched  pledged       state  backers country  usd_pledged  \
# 0 2011-08-17 06:31:31   1145.0    canceled       24      US  1145.000000
# 1 2012-07-23 20:46:48   1851.0      failed       28      US  1851.000000
# 2 2016-07-01 21:55:54   7534.0  successful      254      US  3796.000000
# 3 2017-08-28 15:47:02  16298.0  successful      367      US  2670.000000
# 4 2016-01-25 17:37:10      1.0      failed        1      CA     0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# ### Importer les données

# %%
client.drop_database('exercices')

# %%
client = pymongo.MongoClient()
database = client['exercices']
collection = database['kickstarter']

# Conversion DataFrame -> Liste de dictionnaires
data = df_ks_cleaned.to_dict(orient="records")

# Insertion des données
collection.insert_many(data)

print("Données insérées avec succès !")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[7], line 9
#       6 data = df_ks_cleaned.to_dict(orient="records")
#       8 # Insertion des données
# ----> 9 collection.insert_many(data)
#      11 print("Données insérées avec succès !")
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/collection.py:954, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     952 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     953 blk.ops = list(gen())
# --> 954 blk.execute(write_concern, session, _Op.INSERT)
#     955 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:736, in _Bulk.execute(self, write_concern, session, operation)
#     734         return None
#     735 else:
# --> 736     return self.execute_command(generator, write_concern, session, operation)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/bulk.py:593, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     582     self._execute_command(
#     583         generator,
#     584         write_concern,
#    (...)
#     589         full_result,
#     590     )
#     592 client = self.collection.database.client
# --> 593 _ = client._retryable_write(
#     594     self.is_retryable,
#     595     retryable_bulk,
#     596     session,
#     597     operation,
#     598     bulk=self,  # type: ignore[arg-type]
#     599     operation_id=op_id,
#     600 )
#     602 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     603     _raise_bulk_write_error(full_result)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1898, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1884 """Execute an operation with consecutive retries if possible
#    1885
#    1886 Returns func()'s return value on success. On error retries the same
#    (...)
#    1895 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1896 """
#    1897 with self._tmp_session(session) as s:
# -> 1898     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1784, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1779 # Ensure that the options supports retry_writes and there is a valid session not in
#    1780 # transaction, otherwise, we will not support retry behavior for this txn.
#    1781 retryable = bool(
#    1782     retryable and self.options.retry_writes and session and not session.in_transaction
#    1783 )
# -> 1784 return self._retry_internal(
#    1785     func=func,
#    1786     session=session,
#    1787     bulk=bulk,
#    1788     operation=operation,
#    1789     retryable=retryable,
#    1790     operation_id=operation_id,
#    1791 )
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/_csot.py:120, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     118         with _TimeoutContext(timeout):
#     119             return func(self, *args, **kwargs)
# --> 120 return func(self, *args, **kwargs)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2662, in _ClientConnectionRetryable._write(self)
#    2660 max_wire_version = 0
#    2661 is_mongos = False
# -> 2662 self._server = self._get_server()
#    2663 with self._client._checkout(self._server, self._session) as conn:
#    2664     max_wire_version = conn.max_wire_version
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2645, in _ClientConnectionRetryable._get_server(self)
#    2640 def _get_server(self) -> Server:
#    2641     """Retrieves a server object based on provided object context
#    2642
#    2643     :return: Abstraction to connect to server
#    2644     """
# -> 2645     return self._client._select_server(
#    2646         self._server_selector,
#    2647         self._session,
#    2648         self._operation,
#    2649         address=self._address,
#    2650         deprioritized_servers=self._deprioritized_servers,
#    2651         operation_id=self._operation_id,
#    2652     )
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1649, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1647             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1648     else:
# -> 1649         server = topology.select_server(
#    1650             server_selector,
#    1651             operation,
#    1652             deprioritized_servers=deprioritized_servers,
#    1653             operation_id=operation_id,
#    1654         )
#    1655     return server
#    1656 except PyMongoError as exc:
#    1657     # Server selection errors in a transaction are transient.
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/topology.py:397, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     387 def select_server(
#     388     self,
#     389     selector: Callable[[Selection], Selection],
#    (...)
#     394     operation_id: Optional[int] = None,
#     395 ) -> Server:
#     396     """Like select_servers, but choose a random server if several match."""
# --> 397     server = self._select_server(
#     398         selector,
#     399         operation,
#     400         server_selection_timeout,
#     401         address,
#     402         deprioritized_servers,
#     403         operation_id=operation_id,
#     404     )
#     405     if _csot.get_timeout():
#     406         _csot.set_rtt(server.description.min_round_trip_time)
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/topology.py:375, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     366 def _select_server(
#     367     self,
#     368     selector: Callable[[Selection], Selection],
#    (...)
#     373     operation_id: Optional[int] = None,
#     374 ) -> Server:
# --> 375     servers = self.select_servers(
#     376         selector, operation, server_selection_timeout, address, operation_id
#     377     )
#     378     servers = _filter_servers(servers, deprioritized_servers)
#     379     if len(servers) == 1:
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/topology.py:282, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     279     server_timeout = server_selection_timeout
#     281 with self._lock:
# --> 282     server_descriptions = self._select_servers_loop(
#     283         selector, server_timeout, operation, operation_id, address
#     284     )
#     286     return [
#     287         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     288     ]
#
# File ~/.local/share/virtualenvs/DataEngineerTools-d_IoKyOp/lib/python3.12/site-packages/pymongo/synchronous/topology.py:332, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     321     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     322         _debug_log(
#     323             _SERVER_SELECTION_LOGGER,
#     324             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     330             failure=self._error_message(selector),
#     331         )
# --> 332     raise ServerSelectionTimeoutError(
#     333         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     334     )
#     336 if not logged_waiting:
#     337     _debug_log(
#     338         _SERVER_SELECTION_LOGGER,
#     339         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     345         remainingTimeMS=int(end_time - time.monotonic()),
#     346     )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 675ebfd29329040f0d8fc394, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 61] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
print(client.list_database_names())
print(database.list_collection_names())
# Out:
# ['admin', 'config', 'exercices', 'local', 'series']
# ['kickstarter']

# %% [markdown]
# ## Question 1

# %%
# Récupérer les 5 projets ayant reçu le plus de promesse de dons.

top_pledged_projects = collection.find().sort('pledged', pymongo.DESCENDING).limit(5)

for project in top_pledged_projects:
    print(project['name'], project['pledged'])
# Out:
# COOLEST COOLER: 21st Century Cooler that's Actually Cooler 13285226.36
# Pebble 2, Time 2 + All-New Pebble Core 12779843.49
# Expect the Unexpected. digiFilmï¿½ Camera by YASHICA 10035296.0
# OUYA: A New Kind of Video Game Console 8596474.58
# The Everyday Backpack, Tote, and Sling 6565782.5

# %% [markdown]
# ## Question 2

# %%
# Compter le nombre de projets ayant atteint leur but.

successful_projects_count = collection.count_documents({'state': 'successful'})
print(f"Nombre de projets ayant atteint leur objectif : {successful_projects_count}")
# Out:
# Nombre de projets ayant atteint leur objectif : 52998

# %% [markdown]
# ## Question 3

# %%
# Compter le nombre de projets pour chaque catégorie.

pipeline = [
    {
        '$group': {
            '_id': '$category',  # Regrouper par la catégorie
            'count': {'$sum': 1}  # Compter le nombre de projets dans chaque catégorie
        }
    },
    {
        '$sort': {'count': -1}  # Trier par nombre de projets (descendant)
    }
]

# Exécuter l'agrégation
category_counts = collection.aggregate(pipeline)

# Afficher les résultats
for category in category_counts:
    print(f"Catégorie: {category['_id']}, Nombre de projets: {category['count']}")
# Out:
# Catégorie: Product Design, Nombre de projets: 8885
# Catégorie: Documentary, Nombre de projets: 6497
# Catégorie: Tabletop Games, Nombre de projets: 5579
# Catégorie: Music, Nombre de projets: 5293
# Catégorie: Shorts, Nombre de projets: 4857
# Catégorie: Video Games, Nombre de projets: 4797
# Catégorie: Food, Nombre de projets: 4612
# Catégorie: Fiction, Nombre de projets: 3703
# Catégorie: Film & Video, Nombre de projets: 3657
# Catégorie: Nonfiction, Nombre de projets: 3390
# Catégorie: Fashion, Nombre de projets: 3379
# Catégorie: Art, Nombre de projets: 3358
# Catégorie: Apparel, Nombre de projets: 2827
# Catégorie: Theater, Nombre de projets: 2786
# Catégorie: Rock, Nombre de projets: 2707
# Catégorie: Technology, Nombre de projets: 2689
# Catégorie: Children's Books, Nombre de projets: 2686
# Catégorie: Apps, Nombre de projets: 2535
# Catégorie: Webseries, Nombre de projets: 2316
# Catégorie: Photography, Nombre de projets: 2239
# Catégorie: Indie Rock, Nombre de projets: 2192
# Catégorie: Publishing, Nombre de projets: 2147
# Catégorie: Narrative Film, Nombre de projets: 2097
# Catégorie: Web, Nombre de projets: 2017
# Catégorie: Comics, Nombre de projets: 1931
# Catégorie: Crafts, Nombre de projets: 1834
# Catégorie: Country & Folk, Nombre de projets: 1790
# Catégorie: Design, Nombre de projets: 1641
# Catégorie: Hip-Hop, Nombre de projets: 1555
# Catégorie: Hardware, Nombre de projets: 1430
# Catégorie: Games, Nombre de projets: 1331
# Catégorie: Pop, Nombre de projets: 1302
# Catégorie: Painting, Nombre de projets: 1288
# Catégorie: Illustration, Nombre de projets: 1263
# Catégorie: Public Art, Nombre de projets: 1248
# Catégorie: Gadgets, Nombre de projets: 1210
# Catégorie: Accessories, Nombre de projets: 1203
# Catégorie: Software, Nombre de projets: 1193
# Catégorie: Mixed Media, Nombre de projets: 1118
# Catégorie: Restaurants, Nombre de projets: 1088
# Catégorie: Art Books, Nombre de projets: 1065
# Catégorie: Classical Music, Nombre de projets: 1064
# Catégorie: Comic Books, Nombre de projets: 1032
# Catégorie: Animation, Nombre de projets: 1017
# Catégorie: Drinks, Nombre de projets: 995
# Catégorie: Playing Cards, Nombre de projets: 963
# Catégorie: Comedy, Nombre de projets: 923
# Catégorie: Dance, Nombre de projets: 900
# Catégorie: Drama, Nombre de projets: 871
# Catégorie: Electronic Music, Nombre de projets: 858
# Catégorie: Performance Art, Nombre de projets: 855
# Catégorie: World Music, Nombre de projets: 850
# Catégorie: Graphic Design, Nombre de projets: 765
# Catégorie: Sculpture, Nombre de projets: 737
# Catégorie: Jazz, Nombre de projets: 733
# Catégorie: Graphic Novels, Nombre de projets: 702
# Catégorie: Small Batch, Nombre de projets: 701
# Catégorie: Food Trucks, Nombre de projets: 687
# Catégorie: Journalism, Nombre de projets: 672
# Catégorie: Mobile Games, Nombre de projets: 650
# Catégorie: Photobooks, Nombre de projets: 608
# Catégorie: Plays, Nombre de projets: 539
# Catégorie: Poetry, Nombre de projets: 532
# Catégorie: Horror, Nombre de projets: 525
# Catégorie: Digital Art, Nombre de projets: 524
# Catégorie: Periodicals, Nombre de projets: 517
# Catégorie: Wearables, Nombre de projets: 508
# Catégorie: Farms, Nombre de projets: 482
# Catégorie: DIY, Nombre de projets: 480
# Catégorie: Jewelry, Nombre de projets: 472
# Catégorie: People, Nombre de projets: 440
# Catégorie: Faith, Nombre de projets: 439
# Catégorie: Woodworking, Nombre de projets: 433
# Catégorie: Performances, Nombre de projets: 414
# Catégorie: Television, Nombre de projets: 401
# Catégorie: Live Games, Nombre de projets: 394
# Catégorie: Conceptual Art, Nombre de projets: 393
# Catégorie: Footwear, Nombre de projets: 379
# Catégorie: Academic, Nombre de projets: 367
# Catégorie: Musical, Nombre de projets: 367
# Catégorie: DIY Electronics, Nombre de projets: 358
# Catégorie: Experimental, Nombre de projets: 357
# Catégorie: Radio & Podcasts, Nombre de projets: 349
# Catégorie: Ready-to-wear, Nombre de projets: 332
# Catégorie: Spaces, Nombre de projets: 331
# Catégorie: Young Adult, Nombre de projets: 328
# Catégorie: Events, Nombre de projets: 321
# Catégorie: Festivals, Nombre de projets: 313
# Catégorie: Thrillers, Nombre de projets: 302
# Catégorie: Architecture, Nombre de projets: 300
# Catégorie: Anthologies, Nombre de projets: 300
# Catégorie: Music Videos, Nombre de projets: 299
# Catégorie: Fine Art, Nombre de projets: 290
# Catégorie: Print, Nombre de projets: 287
# Catégorie: Places, Nombre de projets: 283
# Catégorie: Action, Nombre de projets: 282
# Catégorie: Metal, Nombre de projets: 274
# Catégorie: Science Fiction, Nombre de projets: 274
# Catégorie: 3D Printing, Nombre de projets: 271
# Catégorie: Webcomics, Nombre de projets: 259
# Catégorie: Sound, Nombre de projets: 255
# Catégorie: Robots, Nombre de projets: 237
# Catégorie: Vegan, Nombre de projets: 229
# Catégorie: Nature, Nombre de projets: 219
# Catégorie: Cookbooks, Nombre de projets: 217
# Catégorie: Childrenswear, Nombre de projets: 192
# Catégorie: Installations, Nombre de projets: 178
# Catégorie: Gaming Hardware, Nombre de projets: 178
# Catégorie: Farmer's Markets, Nombre de projets: 175
# Catégorie: R&B, Nombre de projets: 172
# Catégorie: Candles, Nombre de projets: 168
# Catégorie: Camera Equipment, Nombre de projets: 165
# Catégorie: Audio, Nombre de projets: 164
# Catégorie: Flight, Nombre de projets: 158
# Catégorie: Video, Nombre de projets: 147
# Catégorie: Interactive Design, Nombre de projets: 146
# Catégorie: Zines, Nombre de projets: 144
# Catégorie: Space Exploration, Nombre de projets: 137
# Catégorie: Fantasy, Nombre de projets: 132
# Catégorie: Immersive, Nombre de projets: 131
# Catégorie: Family, Nombre de projets: 130
# Catégorie: Civic Design, Nombre de projets: 130
# Catégorie: Ceramics, Nombre de projets: 128
# Catégorie: Punk, Nombre de projets: 127
# Catégorie: Literary Journals, Nombre de projets: 118
# Catégorie: Community Gardens, Nombre de projets: 115
# Catégorie: Blues, Nombre de projets: 113
# Catégorie: Calendars, Nombre de projets: 112
# Catégorie: Kids, Nombre de projets: 109
# Catégorie: Couture, Nombre de projets: 108
# Catégorie: Textiles, Nombre de projets: 105
# Catégorie: Animals, Nombre de projets: 97
# Catégorie: Fabrication Tools, Nombre de projets: 96
# Catégorie: Puzzles, Nombre de projets: 95
# Catégorie: Makerspaces, Nombre de projets: 91
# Catégorie: Movie Theaters, Nombre de projets: 90
# Catégorie: Stationery, Nombre de projets: 90
# Catégorie: Printing, Nombre de projets: 83
# Catégorie: Knitting, Nombre de projets: 78
# Catégorie: Bacon, Nombre de projets: 78
# Catégorie: Translations, Nombre de projets: 76
# Catégorie: Romance, Nombre de projets: 74
# Catégorie: Video Art, Nombre de projets: 65
# Catégorie: Latin, Nombre de projets: 63
# Catégorie: Crochet, Nombre de projets: 61
# Catégorie: Workshops, Nombre de projets: 59
# Catégorie: Photo, Nombre de projets: 58
# Catégorie: Glass, Nombre de projets: 51
# Catégorie: Pet Fashion, Nombre de projets: 51
# Catégorie: Embroidery, Nombre de projets: 49
# Catégorie: Typography, Nombre de projets: 44
# Catégorie: Pottery, Nombre de projets: 40
# Catégorie: Weaving, Nombre de projets: 38
# Catégorie: Quilts, Nombre de projets: 32
# Catégorie: Residencies, Nombre de projets: 32
# Catégorie: Letterpress, Nombre de projets: 24
# Catégorie: Chiptune, Nombre de projets: 10
# Catégorie: Literary Spaces, Nombre de projets: 10
# Catégorie: Taxidermy, Nombre de projets: 7

# %% [markdown]
# ## Question 4

# %%
# Compter le nombre de projets français ayant été instanciés avant 2016.

from datetime import datetime

date_limit = datetime(2016, 1, 1)

count = collection.count_documents({
    'country': 'FR',               
    'launched': {'$lt': date_limit}         # Opérateur MongoDB 'less than' : val
})
print(f"Nombre de projets français lancés avant 2016 : {count}")
# Out:
# Nombre de projets français lancés avant 2016 : 330

# %% [markdown]
# ## Question 5

# %%
# Récupérer les projets américains ayant demandé plus de 200 000 dollars.

projects = collection.find({
    'country': 'US',             
    'goal': {'$gt': 200000}         # Opérateur MongoDB 'greater than' : val      
})

for project in projects:
    print(project)
# Out:
# {'_id': ObjectId('6758828ca03ea151f32eabba'), 'ID': 866634482, 'name': 'A CALL TO ADVENTURE', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 9, 14, 0, 0), 'goal': 287000.0, 'launched': datetime.datetime(2012, 8, 13, 23, 14, 2), 'pledged': 1465.0, 'state': 'failed', 'backers': 11, 'country': 'US', 'usd_pledged': 1465.0, 'usd_pledged_real': 1465.0}
# {'_id': ObjectId('6758828ca03ea151f32eac6c'), 'ID': 993194166, 'name': 'Storybricks, the storytelling online RPG', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2012, 6, 1, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2012, 5, 1, 20, 49, 58), 'pledged': 23680.54, 'state': 'failed', 'backers': 409, 'country': 'US', 'usd_pledged': 23680.54, 'usd_pledged_real': 23680.54}
# {'_id': ObjectId('6758828ca03ea151f32eac74'), 'ID': 1147175344, 'name': 'Shine On New World', 'category': 'Theater', 'main_category': 'Theater', 'currency': 'USD', 'deadline': datetime.datetime(2013, 11, 4, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2013, 9, 30, 18, 18, 40), 'pledged': 12314.0, 'state': 'failed', 'backers': 50, 'country': 'US', 'usd_pledged': 12314.0, 'usd_pledged_real': 12314.0}
# {'_id': ObjectId('6758828ca03ea151f32eac83'), 'ID': 2012810303, 'name': 'Nightclub', 'category': 'Music', 'main_category': 'Music', 'currency': 'USD', 'deadline': datetime.datetime(2017, 9, 10, 0, 0), 'goal': 3000000.0, 'launched': datetime.datetime(2017, 8, 11, 18, 8, 7), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32eae04'), 'ID': 593221398, 'name': 'Nastaran (Wild Rose)', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 6, 30, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 5, 8, 21, 3, 20), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eae0b'), 'ID': 621936552, 'name': 'Hubo - Extension Box for iPhone', 'category': 'Gadgets', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2016, 11, 26, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2016, 10, 27, 17, 43, 14), 'pledged': 1996.0, 'state': 'failed', 'backers': 10, 'country': 'US', 'usd_pledged': 438.0, 'usd_pledged_real': 1996.0}
# {'_id': ObjectId('6758828ca03ea151f32eae2a'), 'ID': 1323150226, 'name': 'Baja ATV Park (Suspended)', 'category': 'Live Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2016, 5, 31, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2016, 4, 1, 22, 4, 54), 'pledged': 11.0, 'state': 'suspended', 'backers': 3, 'country': 'US', 'usd_pledged': 11.0, 'usd_pledged_real': 11.0}
# {'_id': ObjectId('6758828ca03ea151f32eae48'), 'ID': 61436443, 'name': 'Chihuly Installation for Orlando (Pulse Nightclub)', 'category': 'Installations', 'main_category': 'Art', 'currency': 'USD', 'deadline': datetime.datetime(2016, 8, 12, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2016, 7, 13, 17, 31, 26), 'pledged': 5.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 4.0, 'usd_pledged_real': 5.0}
# {'_id': ObjectId('6758828ca03ea151f32eaf0d'), 'ID': 821637012, 'name': 'Kurt Vonnegut: Unstuck in Time', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 3, 10, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 2, 10, 14, 5, 34), 'pledged': 300319.0, 'state': 'successful', 'backers': 3755, 'country': 'US', 'usd_pledged': 300319.0, 'usd_pledged_real': 300319.0}
# {'_id': ObjectId('6758828ca03ea151f32eaf5c'), 'ID': 924370408, 'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America', 'category': 'Flight', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2016, 12, 15, 0, 0), 'goal': 3000000.0, 'launched': datetime.datetime(2016, 11, 15, 21, 6, 46), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eaf90'), 'ID': 966762561, 'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 12, 12, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2012, 11, 12, 23, 27, 51), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eafb6'), 'ID': 673847752, 'name': 'Saints of The Classroom', 'category': 'Television', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 11, 18, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2016, 10, 19, 2, 5, 16), 'pledged': 3085.0, 'state': 'failed', 'backers': 24, 'country': 'US', 'usd_pledged': 1915.0, 'usd_pledged_real': 3085.0}
# {'_id': ObjectId('6758828ca03ea151f32eb04e'), 'ID': 1751772364, 'name': 'Hemingwrite - A Distraction Free Digital Typewriter', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2015, 1, 23, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 12, 10, 18, 58, 8), 'pledged': 342471.0, 'state': 'successful', 'backers': 1096, 'country': 'US', 'usd_pledged': 342471.0, 'usd_pledged_real': 342471.0}
# {'_id': ObjectId('6758828ca03ea151f32eb08e'), 'ID': 1529289950, 'name': 'Breakfast 24/7', 'category': 'Food', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2016, 7, 2, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2016, 5, 18, 0, 36, 35), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eb0ba'), 'ID': 314981144, 'name': 'FJE REVOLT', 'category': 'Apparel', 'main_category': 'Fashion', 'currency': 'USD', 'deadline': datetime.datetime(2015, 2, 10, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2015, 1, 14, 3, 1, 52), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eb0bb'), 'ID': 208383561, 'name': 'Austin City Limits 40 Year History Documentary Film', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 9, 30, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2014, 8, 29, 20, 46, 59), 'pledged': 9.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 9.0, 'usd_pledged_real': 9.0}
# {'_id': ObjectId('6758828ca03ea151f32eb108'), 'ID': 912070501, 'name': 'Ozark Mountain Ranch', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 4, 6, 0, 0), 'goal': 466000.0, 'launched': datetime.datetime(2015, 2, 10, 19, 11, 52), 'pledged': 1076.0, 'state': 'failed', 'backers': 5, 'country': 'US', 'usd_pledged': 1076.0, 'usd_pledged_real': 1076.0}
# {'_id': ObjectId('6758828ca03ea151f32eb113'), 'ID': 2116069761, 'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products', 'category': 'Software', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 10, 7, 0, 0), 'goal': 279646.0, 'launched': datetime.datetime(2014, 9, 4, 18, 26, 25), 'pledged': 85.0, 'state': 'failed', 'backers': 7, 'country': 'US', 'usd_pledged': 85.0, 'usd_pledged_real': 85.0}
# {'_id': ObjectId('6758828ca03ea151f32eb12c'), 'ID': 410799527, 'name': 'Guitar Godz VR: A 3D Rock Music Game', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2017, 4, 4, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2017, 3, 28, 19, 0, 52), 'pledged': 22612.0, 'state': 'failed', 'backers': 36, 'country': 'US', 'usd_pledged': 12311.0, 'usd_pledged_real': 22612.0}
# {'_id': ObjectId('6758828ca03ea151f32eb171'), 'ID': 848767036, 'name': "The world's first crowd funded millionaire documentary", 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 5, 24, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2015, 4, 24, 2, 58, 26), 'pledged': 171.0, 'state': 'failed', 'backers': 17, 'country': 'US', 'usd_pledged': 171.0, 'usd_pledged_real': 171.0}
# {'_id': ObjectId('6758828ca03ea151f32eb1d5'), 'ID': 1520402606, 'name': 'Creating an online game, "Perdition Online".', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2013, 11, 15, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2013, 9, 16, 22, 49, 11), 'pledged': 16.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 16.0, 'usd_pledged_real': 16.0}
# {'_id': ObjectId('6758828ca03ea151f32eb234'), 'ID': 376621995, 'name': 'The Adventures of Billy Buskirk', 'category': 'Family', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2017, 10, 14, 0, 0), 'goal': 750000.0, 'launched': datetime.datetime(2017, 8, 15, 19, 49, 31), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32eb311'), 'ID': 1227415659, 'name': 'MY TINSEL TOWN (Canceled)', 'category': 'Apps', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 9, 13, 0, 0), 'goal': 577000.0, 'launched': datetime.datetime(2014, 7, 15, 0, 55, 45), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eb31c'), 'ID': 520101512, 'name': 'Moonlight 5 star (Canceled)', 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2016, 6, 18, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2016, 4, 19, 6, 41, 47), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eb412'), 'ID': 1256627633, 'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)', 'category': 'Mobile Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2016, 6, 26, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2016, 5, 27, 17, 52, 3), 'pledged': 146.0, 'state': 'canceled', 'backers': 3, 'country': 'US', 'usd_pledged': 146.0, 'usd_pledged_real': 146.0}
# {'_id': ObjectId('6758828ca03ea151f32eb43b'), 'ID': 2033979252, 'name': 'ViewCoze.com | Cozy viewing from home (Canceled)', 'category': 'Web', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2016, 2, 1, 0, 0), 'goal': 370000.0, 'launched': datetime.datetime(2015, 12, 10, 23, 55, 54), 'pledged': 80.0, 'state': 'canceled', 'backers': 1, 'country': 'US', 'usd_pledged': 80.0, 'usd_pledged_real': 80.0}
# {'_id': ObjectId('6758828ca03ea151f32eb447'), 'ID': 1751639331, 'name': 'Meet kubo: an electric scooter to carry all your stuff!', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2013, 12, 20, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2013, 11, 20, 6, 0, 7), 'pledged': 56667.0, 'state': 'failed', 'backers': 166, 'country': 'US', 'usd_pledged': 56667.0, 'usd_pledged_real': 56667.0}
# {'_id': ObjectId('6758828ca03ea151f32eb46e'), 'ID': 1178067412, 'name': 'ONEIDNET Social Professional Commercial Corporate Platform', 'category': 'Web', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2017, 3, 24, 0, 0), 'goal': 545539.0, 'launched': datetime.datetime(2017, 2, 22, 19, 24, 24), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32eb4df'), 'ID': 499583381, 'name': 'The Scariest Movie Ever Created', 'category': 'Horror', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 8, 22, 0, 0), 'goal': 100000000.0, 'launched': datetime.datetime(2015, 7, 23, 21, 44, 2), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32eb5d8'), 'ID': 290390319, 'name': 'The SEED Project', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2013, 1, 17, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2012, 12, 18, 23, 1, 12), 'pledged': 35.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 35.0, 'usd_pledged_real': 35.0}
# {'_id': ObjectId('6758828ca03ea151f32eb5f2'), 'ID': 1560972255, 'name': 'NewsRadio Season 6 (Canceled)', 'category': 'Television', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 12, 16, 0, 0), 'goal': 3000000.0, 'launched': datetime.datetime(2015, 10, 17, 0, 40, 32), 'pledged': 101.0, 'state': 'canceled', 'backers': 2, 'country': 'US', 'usd_pledged': 101.0, 'usd_pledged_real': 101.0}
# {'_id': ObjectId('6758828ca03ea151f32eb638'), 'ID': 1876072493, 'name': 'Get Me Me Kids (Books, Music, Film & Games)', 'category': "Children's Books", 'main_category': 'Publishing', 'currency': 'USD', 'deadline': datetime.datetime(2015, 10, 10, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2015, 9, 10, 22, 58, 39), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eb6b7'), 'ID': 1517530930, 'name': "Daniel's Dream", 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 6, 21, 0, 0), 'goal': 2000000.0, 'launched': datetime.datetime(2013, 5, 22, 22, 2, 9), 'pledged': 60.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 60.0, 'usd_pledged_real': 60.0}
# {'_id': ObjectId('6758828ca03ea151f32eb6e5'), 'ID': 658943325, 'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2012, 12, 16, 0, 0), 'goal': 444000.0, 'launched': datetime.datetime(2012, 11, 5, 19, 5, 56), 'pledged': 3439.0, 'state': 'failed', 'backers': 11, 'country': 'US', 'usd_pledged': 3439.0, 'usd_pledged_real': 3439.0}
# {'_id': ObjectId('6758828ca03ea151f32eb723'), 'ID': 420095150, 'name': 'GolferVox', 'category': 'Apps', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2015, 7, 23, 0, 0), 'goal': 1200000.0, 'launched': datetime.datetime(2015, 6, 23, 21, 12, 43), 'pledged': 70.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 70.0, 'usd_pledged_real': 70.0}
# {'_id': ObjectId('6758828ca03ea151f32eb749'), 'ID': 668413973, 'name': 'Power Rangers | fan film reboot movie', 'category': 'Action', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 2, 6, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2015, 12, 8, 21, 34, 39), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32eb81e'), 'ID': 1481048815, 'name': '"Another Network" Film Project', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 5, 15, 0, 0), 'goal': 225000.0, 'launched': datetime.datetime(2014, 3, 31, 22, 46, 31), 'pledged': 55.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 55.0, 'usd_pledged_real': 55.0}
# {'_id': ObjectId('6758828ca03ea151f32eb8db'), 'ID': 1916952451, 'name': 'SELF-SUSTAINING ORGANIC FARM', 'category': 'Farms', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2014, 12, 9, 0, 0), 'goal': 450000.0, 'launched': datetime.datetime(2014, 10, 10, 17, 48, 13), 'pledged': 11.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 11.0, 'usd_pledged_real': 11.0}
# {'_id': ObjectId('6758828ca03ea151f32eb8e1'), 'ID': 1554575493, 'name': 'Fuel-X-Tender', 'category': 'Gadgets', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 7, 31, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2014, 7, 1, 4, 18, 43), 'pledged': 272.0, 'state': 'failed', 'backers': 6, 'country': 'US', 'usd_pledged': 272.0, 'usd_pledged_real': 272.0}
# {'_id': ObjectId('6758828ca03ea151f32eb8f6'), 'ID': 1601085300, 'name': 'Salad Barr ( the new fast food restaurant )', 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2016, 3, 26, 0, 0), 'goal': 270000.0, 'launched': datetime.datetime(2016, 2, 26, 0, 4, 18), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32eb8fe'), 'ID': 1636574067, 'name': 'We want your money (Suspended)', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2016, 8, 3, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2016, 6, 4, 16, 51, 18), 'pledged': 123.0, 'state': 'suspended', 'backers': 3, 'country': 'US', 'usd_pledged': 123.0, 'usd_pledged_real': 123.0}
# {'_id': ObjectId('6758828ca03ea151f32eb95b'), 'ID': 773987836, 'name': "Dutch's Kegs", 'category': 'Small Batch', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2015, 12, 22, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2015, 11, 17, 23, 36, 6), 'pledged': 260.0, 'state': 'failed', 'backers': 17, 'country': 'US', 'usd_pledged': 260.0, 'usd_pledged_real': 260.0}
# {'_id': ObjectId('6758828ca03ea151f32eb982'), 'ID': 1831435950, 'name': 'Pro Tailgater Party Plate', 'category': 'Gadgets', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2017, 5, 31, 0, 0), 'goal': 365000.0, 'launched': datetime.datetime(2017, 4, 25, 21, 25, 17), 'pledged': 200.0, 'state': 'failed', 'backers': 4, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 200.0}
# {'_id': ObjectId('6758828ca03ea151f32eb98c'), 'ID': 178255149, 'name': 'Gabriel Device - Free energy for everyone', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2017, 12, 14, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2017, 11, 14, 1, 35, 25), 'pledged': 81.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 40.0, 'usd_pledged_real': 81.0}
# {'_id': ObjectId('6758828ca03ea151f32eb9c4'), 'ID': 1098261281, 'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2017, 11, 30, 0, 0), 'goal': 875000.0, 'launched': datetime.datetime(2017, 10, 31, 6, 35, 30), 'pledged': 5.0, 'state': 'canceled', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 5.0}
# {'_id': ObjectId('6758828ca03ea151f32eba2c'), 'ID': 849179016, 'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2017, 4, 25, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2017, 3, 11, 3, 10, 44), 'pledged': 710.0, 'state': 'failed', 'backers': 5, 'country': 'US', 'usd_pledged': 200.0, 'usd_pledged_real': 710.0}
# {'_id': ObjectId('6758828ca03ea151f32eba71'), 'ID': 1855118124, 'name': 'Sonic Chao World fan game (Canceled)', 'category': 'Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2015, 2, 14, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2015, 1, 15, 23, 33, 34), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ebaef'), 'ID': 607916149, 'name': 'The Darkest Dawn', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 6, 28, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2013, 5, 29, 4, 48, 42), 'pledged': 5.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 5.0, 'usd_pledged_real': 5.0}
# {'_id': ObjectId('6758828ca03ea151f32ebb94'), 'ID': 696960534, 'name': 'Adventure Combat Ops - A real life, apocalyptic video game!', 'category': 'Live Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2014, 7, 24, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2014, 6, 24, 1, 26, 37), 'pledged': 320.0, 'state': 'failed', 'backers': 5, 'country': 'US', 'usd_pledged': 320.0, 'usd_pledged_real': 320.0}
# {'_id': ObjectId('6758828ca03ea151f32ebbd2'), 'ID': 2053440575, 'name': "World's First Smart Football", 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2015, 5, 3, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2015, 4, 3, 1, 17, 58), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32ebc19'), 'ID': 397353040, 'name': 'The Maryanne Godboldo Story (Canceled)', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 7, 20, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2013, 6, 20, 1, 17, 50), 'pledged': 2350.0, 'state': 'canceled', 'backers': 45, 'country': 'US', 'usd_pledged': 2350.0, 'usd_pledged_real': 2350.0}
# {'_id': ObjectId('6758828ca03ea151f32ebc43'), 'ID': 534082236, 'name': 'M.A.C.S. (Canceled)', 'category': 'Space Exploration', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 12, 8, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2014, 10, 24, 20, 53, 50), 'pledged': 8.0, 'state': 'canceled', 'backers': 4, 'country': 'US', 'usd_pledged': 8.0, 'usd_pledged_real': 8.0}
# {'_id': ObjectId('6758828ca03ea151f32ebc95'), 'ID': 1957695328, 'name': 'Planetary Annihilation - A Next Generation RTS', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2012, 9, 14, 0, 0), 'goal': 900000.0, 'launched': datetime.datetime(2012, 8, 15, 21, 20, 10), 'pledged': 2229344.36, 'state': 'successful', 'backers': 44162, 'country': 'US', 'usd_pledged': 2229344.36, 'usd_pledged_real': 2229344.36}
# {'_id': ObjectId('6758828ca03ea151f32ebc97'), 'ID': 1618218442, 'name': "Pontruff's Pop Shop, Pizza, and Punk Rock", 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2014, 9, 26, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2014, 7, 28, 9, 5, 22), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ebd5e'), 'ID': 1402370273, 'name': 'The Good Fight of Faith', 'category': 'Family', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 11, 19, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2015, 10, 20, 0, 56, 49), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ebd8a'), 'ID': 410651072, 'name': 'Film Adaptation of "The Traveler"', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 10, 31, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2016, 10, 1, 19, 42, 33), 'pledged': 25.0, 'state': 'canceled', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 25.0}
# {'_id': ObjectId('6758828ca03ea151f32ebe69'), 'ID': 489938719, 'name': 'Uncommon Wealth', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 11, 24, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2013, 9, 25, 18, 39, 9), 'pledged': 2110.0, 'state': 'failed', 'backers': 18, 'country': 'US', 'usd_pledged': 2110.0, 'usd_pledged_real': 2110.0}
# {'_id': ObjectId('6758828ca03ea151f32ebe79'), 'ID': 1730464042, 'name': 'Design the Starship Enterprise Science Research Mock Up', 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2013, 12, 2, 0, 0), 'goal': 313550.0, 'launched': datetime.datetime(2013, 10, 18, 9, 18, 13), 'pledged': 31.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 31.0, 'usd_pledged_real': 31.0}
# {'_id': ObjectId('6758828ca03ea151f32ebed8'), 'ID': 1517172285, 'name': 'Backyard Soccer Buddy / Football Mate (Overseas)', 'category': 'Gadgets', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2016, 9, 15, 0, 0), 'goal': 2000000.0, 'launched': datetime.datetime(2016, 7, 20, 18, 37, 9), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ebf26'), 'ID': 1523176093, 'name': '"anonymous (street meat)" (Canceled)', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 6, 17, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2012, 5, 18, 8, 18, 34), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec027'), 'ID': 934554143, 'name': 'Hello Space Boy!', 'category': 'Animation', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 7, 31, 0, 0), 'goal': 2000000.0, 'launched': datetime.datetime(2016, 6, 3, 23, 59, 11), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec049'), 'ID': 1452500654, 'name': 'Interactive Breastfeeding Documentary', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2011, 9, 20, 0, 0), 'goal': 210000.0, 'launched': datetime.datetime(2011, 8, 2, 15, 54, 48), 'pledged': 12058.3, 'state': 'failed', 'backers': 117, 'country': 'US', 'usd_pledged': 12058.3, 'usd_pledged_real': 12058.3}
# {'_id': ObjectId('6758828ca03ea151f32ec055'), 'ID': 1783703627, 'name': 'Aquaponics system for supplying fresh organic food.', 'category': 'Farms', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2016, 6, 5, 0, 0), 'goal': 8000000.0, 'launched': datetime.datetime(2016, 4, 6, 20, 30, 5), 'pledged': 21.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 21.0, 'usd_pledged_real': 21.0}
# {'_id': ObjectId('6758828ca03ea151f32ec0a3'), 'ID': 1028997654, 'name': 'After Reset RPG', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2013, 12, 11, 0, 0), 'goal': 900000.0, 'launched': datetime.datetime(2013, 11, 11, 10, 41, 59), 'pledged': 47939.0, 'state': 'failed', 'backers': 1362, 'country': 'US', 'usd_pledged': 47939.0, 'usd_pledged_real': 47939.0}
# {'_id': ObjectId('6758828ca03ea151f32ec0da'), 'ID': 731780695, 'name': 'SLAYING GIANTS #GOLIATH', 'category': 'Movie Theaters', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 8, 20, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2016, 7, 21, 3, 42, 14), 'pledged': 2508.0, 'state': 'failed', 'backers': 26, 'country': 'US', 'usd_pledged': 175.0, 'usd_pledged_real': 2508.0}
# {'_id': ObjectId('6758828ca03ea151f32ec103'), 'ID': 776004598, 'name': 'Fan News', 'category': 'Journalism', 'main_category': 'Journalism', 'currency': 'USD', 'deadline': datetime.datetime(2015, 3, 19, 0, 0), 'goal': 275000.0, 'launched': datetime.datetime(2015, 2, 17, 19, 40, 55), 'pledged': 10.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 10.0, 'usd_pledged_real': 10.0}
# {'_id': ObjectId('6758828ca03ea151f32ec126'), 'ID': 580110957, 'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2016, 11, 5, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2016, 9, 21, 20, 21, 50), 'pledged': 1865.0, 'state': 'failed', 'backers': 14, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1865.0}
# {'_id': ObjectId('6758828ca03ea151f32ec18c'), 'ID': 644614031, 'name': "Iota: Never lose sight of what's important.", 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 8, 14, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 7, 15, 8, 19, 5), 'pledged': 282155.0, 'state': 'successful', 'backers': 1657, 'country': 'US', 'usd_pledged': 282155.0, 'usd_pledged_real': 282155.0}
# {'_id': ObjectId('6758828ca03ea151f32ec1fb'), 'ID': 281465042, 'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 6, 15, 0, 0), 'goal': 2000000.0, 'launched': datetime.datetime(2014, 5, 1, 20, 1, 10), 'pledged': 225.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 225.0, 'usd_pledged_real': 225.0}
# {'_id': ObjectId('6758828ca03ea151f32ec205'), 'ID': 588787421, 'name': 'jfg76tukv u', 'category': 'Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': datetime.datetime(2015, 12, 31, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 11, 19, 16, 47, 3), 'pledged': 2.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 2.0, 'usd_pledged_real': 2.0}
# {'_id': ObjectId('6758828ca03ea151f32ec223'), 'ID': 742934297, 'name': 'Shaft in Asia Featured Film', 'category': 'Action', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 10, 13, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2015, 8, 14, 22, 56, 40), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec24b'), 'ID': 715019941, 'name': 'P.U.R.E. Gamers', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2015, 10, 4, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2015, 8, 6, 22, 22), 'pledged': 25.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 25.0, 'usd_pledged_real': 25.0}
# {'_id': ObjectId('6758828ca03ea151f32ec2a3'), 'ID': 818541249, 'name': 'The Hawaiian Girl Art Studio (Canceled)', 'category': 'Digital Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': datetime.datetime(2016, 3, 24, 0, 0), 'goal': 1100000.0, 'launched': datetime.datetime(2016, 1, 26, 5, 48, 5), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec4a3'), 'ID': 1051776765, 'name': 'Independent Broadcasting Company', 'category': 'Television', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2017, 5, 31, 0, 0), 'goal': 700000.0, 'launched': datetime.datetime(2017, 4, 1, 2, 34, 51), 'pledged': 56.0, 'state': 'canceled', 'backers': 3, 'country': 'US', 'usd_pledged': 56.0, 'usd_pledged_real': 56.0}
# {'_id': ObjectId('6758828ca03ea151f32ec500'), 'ID': 595664945, 'name': 'Forbidden Woods (Canceled)', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 8, 18, 0, 0), 'goal': 2300000.0, 'launched': datetime.datetime(2012, 7, 19, 21, 12, 51), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec567'), 'ID': 788197692, 'name': 'The Guilt Free Life', 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2014, 8, 27, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 6, 28, 22, 5, 3), 'pledged': 20.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 20.0, 'usd_pledged_real': 20.0}
# {'_id': ObjectId('6758828ca03ea151f32ec56f'), 'ID': 1254965074, 'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca', 'category': 'Small Batch', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2015, 4, 19, 0, 0), 'goal': 780000.0, 'launched': datetime.datetime(2015, 2, 18, 17, 23, 50), 'pledged': 267.0, 'state': 'failed', 'backers': 6, 'country': 'US', 'usd_pledged': 267.0, 'usd_pledged_real': 267.0}
# {'_id': ObjectId('6758828ca03ea151f32ec57d'), 'ID': 178418310, 'name': 'Puzzle Camp', 'category': 'Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2014, 6, 18, 0, 0), 'goal': 750000.0, 'launched': datetime.datetime(2014, 5, 19, 3, 56, 46), 'pledged': 35.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 35.0, 'usd_pledged_real': 35.0}
# {'_id': ObjectId('6758828ca03ea151f32ec580'), 'ID': 1473597203, 'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo', 'category': 'Sound', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2018, 1, 11, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2017, 12, 12, 18, 46, 26), 'pledged': 5651.0, 'state': 'live', 'backers': 14, 'country': 'US', 'usd_pledged': 1248.0, 'usd_pledged_real': 5651.0}
# {'_id': ObjectId('6758828ca03ea151f32ec59f'), 'ID': 715203303, 'name': "THE YING YANG MURDER MYSTERY'S (Canceled)", 'category': 'Webseries', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 12, 31, 0, 0), 'goal': 900000.0, 'launched': datetime.datetime(2014, 12, 1, 23, 50, 57), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec5b3'), 'ID': 374403417, 'name': 'Montgomery Al Concert 5FDP and VOLBEAT', 'category': 'Rock', 'main_category': 'Music', 'currency': 'USD', 'deadline': datetime.datetime(2014, 7, 24, 0, 0), 'goal': 1040000.0, 'launched': datetime.datetime(2014, 6, 24, 2, 58, 50), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec5b9'), 'ID': 1935538858, 'name': 'Wall Scaler', 'category': 'Flight', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2017, 4, 17, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2017, 3, 3, 21, 30, 39), 'pledged': 1.0, 'state': 'suspended', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32ec5ed'), 'ID': 1926637288, 'name': 'Historic B&B with an in-house French Bakery in Memphis, TN', 'category': 'Food', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2016, 7, 23, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2016, 6, 23, 1, 13, 20), 'pledged': 10100.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 10100.0, 'usd_pledged_real': 10100.0}
# {'_id': ObjectId('6758828ca03ea151f32ec645'), 'ID': 1715597415, 'name': 'Angelz Landing the Movie', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 2, 17, 0, 0), 'goal': 1200000.0, 'launched': datetime.datetime(2014, 1, 13, 19, 8, 9), 'pledged': 356.0, 'state': 'failed', 'backers': 5, 'country': 'US', 'usd_pledged': 356.0, 'usd_pledged_real': 356.0}
# {'_id': ObjectId('6758828ca03ea151f32ec6c2'), 'ID': 779336498, 'name': 'Morrison Land', 'category': 'Movie Theaters', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 7, 27, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 5, 28, 19, 42, 35), 'pledged': 10.0, 'state': 'failed', 'backers': 6, 'country': 'US', 'usd_pledged': 10.0, 'usd_pledged_real': 10.0}
# {'_id': ObjectId('6758828ca03ea151f32ec6dd'), 'ID': 1934580784, 'name': 'Triple Espresso Goes to The Big Apple', 'category': 'Theater', 'main_category': 'Theater', 'currency': 'USD', 'deadline': datetime.datetime(2013, 3, 16, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2013, 2, 9, 21, 1, 57), 'pledged': 27581.0, 'state': 'failed', 'backers': 116, 'country': 'US', 'usd_pledged': 27581.0, 'usd_pledged_real': 27581.0}
# {'_id': ObjectId('6758828ca03ea151f32ec7a5'), 'ID': 1596314651, 'name': 'Take And Seek the Movie', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 9, 16, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2013, 8, 16, 4, 59, 36), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec7be'), 'ID': 1834526569, 'name': 'Unsung Story: Tale of the Guardians', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2014, 2, 15, 0, 0), 'goal': 600000.0, 'launched': datetime.datetime(2014, 1, 14, 19, 3, 30), 'pledged': 660126.51, 'state': 'successful', 'backers': 15824, 'country': 'US', 'usd_pledged': 660126.51, 'usd_pledged_real': 660126.51}
# {'_id': ObjectId('6758828ca03ea151f32ec869'), 'ID': 2007557271, 'name': 'Harishwar Center for Arts, Spirituality & Sustainability', 'category': 'Architecture', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2016, 2, 3, 0, 0), 'goal': 1800000.0, 'launched': datetime.datetime(2016, 1, 4, 20, 26, 57), 'pledged': 614.0, 'state': 'failed', 'backers': 14, 'country': 'US', 'usd_pledged': 614.0, 'usd_pledged_real': 614.0}
# {'_id': ObjectId('6758828ca03ea151f32ec873'), 'ID': 695668947, 'name': "The Cancer Patient's Film Project", 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 8, 17, 0, 0), 'goal': 1500000.0, 'launched': datetime.datetime(2013, 7, 12, 2, 38, 19), 'pledged': 275.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 275.0, 'usd_pledged_real': 275.0}
# {'_id': ObjectId('6758828ca03ea151f32ec892'), 'ID': 832080779, 'name': "Small Change: Kids' Financial Life Skills", 'category': 'Software', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 8, 11, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 7, 17, 15, 54, 12), 'pledged': 3536.0, 'state': 'failed', 'backers': 39, 'country': 'US', 'usd_pledged': 3536.0, 'usd_pledged_real': 3536.0}
# {'_id': ObjectId('6758828ca03ea151f32ec906'), 'ID': 1656648684, 'name': 'Save the Williamsburg', 'category': 'Public Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': datetime.datetime(2015, 10, 27, 0, 0), 'goal': 40000000.0, 'launched': datetime.datetime(2015, 9, 27, 15, 8, 5), 'pledged': 21700.0, 'state': 'failed', 'backers': 15, 'country': 'US', 'usd_pledged': 21700.0, 'usd_pledged_real': 21700.0}
# {'_id': ObjectId('6758828ca03ea151f32ec94c'), 'ID': 256448010, 'name': 'Nephilim, Nazis and the New World Order', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 7, 12, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2015, 5, 13, 3, 45, 32), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ec95c'), 'ID': 978588144, 'name': 'War At Home', 'category': 'Drama', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 11, 28, 0, 0), 'goal': 340000.0, 'launched': datetime.datetime(2015, 10, 29, 16, 0, 52), 'pledged': 19328.0, 'state': 'failed', 'backers': 273, 'country': 'US', 'usd_pledged': 19328.0, 'usd_pledged_real': 19328.0}
# {'_id': ObjectId('6758828ca03ea151f32ec9c9'), 'ID': 208391519, 'name': 'North East', 'category': 'Drama', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2017, 7, 23, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2017, 5, 24, 0, 17, 26), 'pledged': 2.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 2.0}
# {'_id': ObjectId('6758828ca03ea151f32ec9e8'), 'ID': 1789241689, 'name': 'The Great Pyramid, Project USA', 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 8, 1, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2014, 6, 2, 15, 53, 58), 'pledged': 35.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 35.0, 'usd_pledged_real': 35.0}
# {'_id': ObjectId('6758828ca03ea151f32eca25'), 'ID': 2126842880, 'name': 'Time travel app', 'category': 'Apps', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2017, 10, 9, 0, 0), 'goal': 375000.0, 'launched': datetime.datetime(2017, 9, 12, 21, 6, 34), 'pledged': 135.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 10.0, 'usd_pledged_real': 135.0}
# {'_id': ObjectId('6758828ca03ea151f32eca77'), 'ID': 1046230768, 'name': 'Honolulu Haze (Canceled)', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 7, 7, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2013, 5, 8, 18, 0, 16), 'pledged': 70.0, 'state': 'canceled', 'backers': 2, 'country': 'US', 'usd_pledged': 70.0, 'usd_pledged_real': 70.0}
# {'_id': ObjectId('6758828ca03ea151f32ecb16'), 'ID': 2135350794, 'name': 'Motor Sports Mailboxes', 'category': 'Crafts', 'main_category': 'Crafts', 'currency': 'USD', 'deadline': datetime.datetime(2015, 1, 18, 0, 0), 'goal': 600000.0, 'launched': datetime.datetime(2014, 11, 19, 20, 20, 55), 'pledged': 200.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 200.0, 'usd_pledged_real': 200.0}
# {'_id': ObjectId('6758828ca03ea151f32ecba6'), 'ID': 381953552, 'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 10, 8, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2014, 9, 3, 1, 33, 36), 'pledged': 60.0, 'state': 'canceled', 'backers': 3, 'country': 'US', 'usd_pledged': 60.0, 'usd_pledged_real': 60.0}
# {'_id': ObjectId('6758828ca03ea151f32eccfd'), 'ID': 749406436, 'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2015, 10, 22, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2015, 9, 17, 16, 39, 3), 'pledged': 257275.0, 'state': 'failed', 'backers': 239, 'country': 'US', 'usd_pledged': 257275.0, 'usd_pledged_real': 257275.0}
# {'_id': ObjectId('6758828ca03ea151f32ecd45'), 'ID': 1812682282, 'name': 'Make A South African Feature Film! (Canceled)', 'category': 'Narrative Film', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2011, 12, 31, 0, 0), 'goal': 2500000.0, 'launched': datetime.datetime(2011, 12, 5, 17, 22, 45), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f32ecde4'), 'ID': 892520897, 'name': 'Feature-Length Movie: Secret of the Missing Grave', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 7, 2, 0, 0), 'goal': 10000000.0, 'launched': datetime.datetime(2013, 5, 3, 23, 15, 16), 'pledged': 11975.0, 'state': 'failed', 'backers': 24, 'country': 'US', 'usd_pledged': 11975.0, 'usd_pledged_real': 11975.0}
# {'_id': ObjectId('6758828ca03ea151f32ece12'), 'ID': 396599619, 'name': "Hey Chicago  It's all about you!", 'category': 'Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2015, 10, 1, 0, 0), 'goal': 380000.0, 'launched': datetime.datetime(2015, 8, 17, 9, 43, 37), 'pledged': 950.0, 'state': 'failed', 'backers': 7, 'country': 'US', 'usd_pledged': 950.0, 'usd_pledged_real': 950.0}
# {'_id': ObjectId('6758828ca03ea151f32ece54'), 'ID': 2028395602, 'name': 'All Points Bulletin (APB): Vendetta', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2013, 5, 1, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2013, 3, 27, 4, 5, 39), 'pledged': 27614.0, 'state': 'failed', 'backers': 161, 'country': 'US', 'usd_pledged': 27614.0, 'usd_pledged_real': 27614.0}
# {'_id': ObjectId('6758828ca03ea151f32ece9c'), 'ID': 233857280, 'name': 'As Cine On TV', 'category': 'Translations', 'main_category': 'Publishing', 'currency': 'USD', 'deadline': datetime.datetime(2017, 4, 29, 0, 0), 'goal': 2000000.0, 'launched': datetime.datetime(2017, 3, 30, 5, 36, 14), 'pledged': 192.0, 'state': 'failed', 'backers': 4, 'country': 'US', 'usd_pledged': 50.0, 'usd_pledged_real': 192.0}
# {'_id': ObjectId('6758828ca03ea151f32ecea7'), 'ID': 1489384109, 'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap', 'category': 'Technology', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2017, 10, 15, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2017, 8, 16, 15, 47, 26), 'pledged': 48307.0, 'state': 'canceled', 'backers': 325, 'country': 'US', 'usd_pledged': 9302.0, 'usd_pledged_real': 48307.0}
# {'_id': ObjectId('6758828ca03ea151f32ecff4'), 'ID': 515152452, 'name': 'Love Gives Hope Art Gallery for Cultural Diversity!', 'category': 'Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': datetime.datetime(2017, 9, 12, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2017, 8, 13, 23, 22, 40), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32ed013'), 'ID': 549303222, 'name': 'The "Get Home Now" Device', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2014, 11, 14, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 9, 30, 19, 45, 59), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f32ed0dd'), 'ID': 599813105, 'name': 'In Pursuit of Passion - Travel Television Series', 'category': 'Television', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 6, 6, 0, 0), 'goal': 280000.0, 'launched': datetime.datetime(2016, 5, 7, 0, 56, 56), 'pledged': 100.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 100.0, 'usd_pledged_real': 100.0}
# {'_id': ObjectId('6758828ca03ea151f32ed10a'), 'ID': 1327325648, 'name': 'Welcome to the Wonderful World of AIDS', 'category': 'Thrillers', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 11, 26, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2014, 10, 27, 4, 27, 59), 'pledged': 2827.0, 'state': 'failed', 'backers': 24, 'country': 'US', 'usd_pledged': 2827.0, 'usd_pledged_real': 2827.0}
# {'_id': ObjectId('6758828ca03ea151f32ed127'), 'ID': 35012487, 'name': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT', 'category': 'Public Art', 'main_category': 'Art', 'currency': 'USD', 'deadline': datetime.datetime(2016, 3, 21, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2016, 1, 21, 23, 34, 11), 'pledged': 116.0, 'state': 'failed', 'backers': 5, 'country': 'US', 'usd_pledged': 116.0, 'usd_pledged_real': 116.0}
# {'_id': ObjectId('6758828ca03ea151f32ed165'), 'ID': 1109856918, 'name': 'From Dawson to Jackson Vineyards', 'category': 'Farms', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2014, 10, 2, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2014, 9, 2, 23, 28, 18), 'pledged': 25.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 25.0, 'usd_pledged_real': 25.0}
# ...
# {'_id': ObjectId('6758828ca03ea151f330e279'), 'ID': 1969755768, 'name': 'The War On Truth - Documentary', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 8, 27, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 7, 28, 21, 58, 30), 'pledged': 1.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f330e27b'), 'ID': 1198265112, 'name': 'MONSTER FEST (Canceled)', 'category': 'Electronic Music', 'main_category': 'Music', 'currency': 'USD', 'deadline': datetime.datetime(2014, 2, 12, 0, 0), 'goal': 225000.0, 'launched': datetime.datetime(2014, 1, 13, 22, 10, 16), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330e31a'), 'ID': 1512058173, 'name': 'Oblivion Seed', 'category': 'Animation', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 3, 19, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2016, 1, 19, 20, 7, 14), 'pledged': 3.0, 'state': 'failed', 'backers': 3, 'country': 'US', 'usd_pledged': 3.0, 'usd_pledged_real': 3.0}
# {'_id': ObjectId('6758828ca03ea151f330e349'), 'ID': 1105649293, 'name': 'DREAD: Book of Lovecraft', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2014, 12, 2, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 10, 31, 16, 11, 54), 'pledged': 1705.0, 'state': 'failed', 'backers': 45, 'country': 'US', 'usd_pledged': 1705.0, 'usd_pledged_real': 1705.0}
# {'_id': ObjectId('6758828ca03ea151f330e44a'), 'ID': 726245303, 'name': 'The Surrender Movie Project', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 8, 3, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2015, 7, 4, 6, 30, 20), 'pledged': 9405.0, 'state': 'failed', 'backers': 65, 'country': 'US', 'usd_pledged': 9405.0, 'usd_pledged_real': 9405.0}
# {'_id': ObjectId('6758828ca03ea151f330e44e'), 'ID': 1658680433, 'name': "Rose and Thistle Cafe'", 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2015, 7, 1, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2015, 5, 28, 3, 12, 45), 'pledged': 302.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 302.0, 'usd_pledged_real': 302.0}
# {'_id': ObjectId('6758828ca03ea151f330e55f'), 'ID': 263507280, 'name': 'The Chronicles Of The Green Mile Club', 'category': 'Fiction', 'main_category': 'Publishing', 'currency': 'USD', 'deadline': datetime.datetime(2014, 8, 27, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 7, 28, 20, 49, 54), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330e586'), 'ID': 1137162248, 'name': 'No Blood...Just Diamonds...American Woodie in Sierra Leone', 'category': 'Television', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 3, 13, 0, 0), 'goal': 450000.0, 'launched': datetime.datetime(2015, 2, 10, 5, 54, 23), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330e58c'), 'ID': 442458047, 'name': 'A Place to Gather Writing Center, LLC', 'category': 'Fiction', 'main_category': 'Publishing', 'currency': 'USD', 'deadline': datetime.datetime(2015, 3, 28, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2015, 2, 26, 5, 16, 22), 'pledged': 10.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 10.0, 'usd_pledged_real': 10.0}
# {'_id': ObjectId('6758828ca03ea151f330e629'), 'ID': 314138987, 'name': 'Choices', 'category': 'Drama', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 10, 9, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2014, 9, 3, 19, 7, 30), 'pledged': 1775.0, 'state': 'failed', 'backers': 7, 'country': 'US', 'usd_pledged': 1775.0, 'usd_pledged_real': 1775.0}
# {'_id': ObjectId('6758828ca03ea151f330e6eb'), 'ID': 263722455, 'name': 'Interactive Smart Tables', 'category': 'Hardware', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2015, 3, 16, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 1, 15, 18, 27, 16), 'pledged': 27.0, 'state': 'failed', 'backers': 4, 'country': 'US', 'usd_pledged': 27.0, 'usd_pledged_real': 27.0}
# {'_id': ObjectId('6758828ca03ea151f330e764'), 'ID': 441893656, 'name': 'The Blue Eagle California Times Shoppers Bargain Guide', 'category': 'Publishing', 'main_category': 'Publishing', 'currency': 'USD', 'deadline': datetime.datetime(2014, 8, 11, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 7, 12, 7, 33, 1), 'pledged': 40.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 40.0, 'usd_pledged_real': 40.0}
# {'_id': ObjectId('6758828ca03ea151f330e83b'), 'ID': 137744472, 'name': 'CitriSlicer - a clean, simple method to serve sliced lemons', 'category': 'Food', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2015, 5, 15, 0, 0), 'goal': 390000.0, 'launched': datetime.datetime(2015, 4, 22, 2, 50, 11), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330e8c7'), 'ID': 1270104074, 'name': 'Republique by Camouflaj + Logan', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2012, 5, 12, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2012, 4, 10, 14, 37, 30), 'pledged': 555662.86, 'state': 'successful', 'backers': 11611, 'country': 'US', 'usd_pledged': 555662.86, 'usd_pledged_real': 555662.86}
# {'_id': ObjectId('6758828ca03ea151f330e8d7'), 'ID': 1169194659, 'name': 'An Old Fashion Butcher Shop', 'category': 'Bacon', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2015, 6, 1, 0, 0), 'goal': 650000.0, 'launched': datetime.datetime(2015, 4, 12, 2, 23, 2), 'pledged': 100.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 100.0, 'usd_pledged_real': 100.0}
# {'_id': ObjectId('6758828ca03ea151f330e8f7'), 'ID': 1390839424, 'name': 'A-List Celebrity, Hollywood Produced LGBT Reality Series', 'category': 'Webseries', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2011, 12, 21, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2011, 10, 22, 2, 13, 1), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330e96c'), 'ID': 1859958347, 'name': 'Help Archie Comics Build a New Riverdale (Canceled)', 'category': 'Comic Books', 'main_category': 'Comics', 'currency': 'USD', 'deadline': datetime.datetime(2015, 6, 10, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2015, 5, 11, 15, 22, 6), 'pledged': 34506.0, 'state': 'canceled', 'backers': 642, 'country': 'US', 'usd_pledged': 34506.0, 'usd_pledged_real': 34506.0}
# {'_id': ObjectId('6758828ca03ea151f330e98e'), 'ID': 1654340432, 'name': 'END - The Online Zombie Survival RTS (Canceled)', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2012, 7, 18, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2012, 6, 8, 16, 38, 45), 'pledged': 295.0, 'state': 'canceled', 'backers': 11, 'country': 'US', 'usd_pledged': 295.0, 'usd_pledged_real': 295.0}
# {'_id': ObjectId('6758828ca03ea151f330e99a'), 'ID': 668609580, 'name': 'Visual Legal Dictionary', 'category': 'Webseries', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2016, 11, 30, 0, 0), 'goal': 800000.0, 'launched': datetime.datetime(2016, 10, 14, 19, 50, 51), 'pledged': 1000.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 1000.0}
# {'_id': ObjectId('6758828ca03ea151f330ea5e'), 'ID': 1627625206, 'name': '207 - The Documentary (Canceled)', 'category': 'Documentary', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 11, 18, 0, 0), 'goal': 845000.0, 'launched': datetime.datetime(2012, 9, 19, 23, 41, 28), 'pledged': 1310.0, 'state': 'canceled', 'backers': 12, 'country': 'US', 'usd_pledged': 1310.0, 'usd_pledged_real': 1310.0}
# {'_id': ObjectId('6758828ca03ea151f330ea64'), 'ID': 1782141039, 'name': 'Otaku Club House', 'category': 'Tabletop Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2016, 5, 2, 0, 0), 'goal': 1949000.0, 'launched': datetime.datetime(2016, 3, 3, 1, 28, 9), 'pledged': 1337.0, 'state': 'failed', 'backers': 11, 'country': 'US', 'usd_pledged': 1337.0, 'usd_pledged_real': 1337.0}
# {'_id': ObjectId('6758828ca03ea151f330ea80'), 'ID': 471353212, 'name': 'VEGETABLE UPRISING URBAN ROOFTOP FARM (Canceled)', 'category': 'Food', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2013, 11, 15, 0, 0), 'goal': 336000.0, 'launched': datetime.datetime(2013, 10, 25, 3, 58, 40), 'pledged': 2451.0, 'state': 'canceled', 'backers': 30, 'country': 'US', 'usd_pledged': 2451.0, 'usd_pledged_real': 2451.0}
# {'_id': ObjectId('6758828ca03ea151f330eac9'), 'ID': 2144858142, 'name': 'The Renaissance Man', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 12, 12, 0, 0), 'goal': 400000.0, 'launched': datetime.datetime(2013, 11, 12, 21, 51, 33), 'pledged': 1025.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 1025.0, 'usd_pledged_real': 1025.0}
# {'_id': ObjectId('6758828ca03ea151f330eb59'), 'ID': 2137561548, 'name': "World's Greatest Card Tricks Ever Revealed", 'category': 'Nonfiction', 'main_category': 'Publishing', 'currency': 'USD', 'deadline': datetime.datetime(2014, 4, 5, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2014, 2, 4, 23, 36, 33), 'pledged': 140.0, 'state': 'failed', 'backers': 7, 'country': 'US', 'usd_pledged': 140.0, 'usd_pledged_real': 140.0}
# {'_id': ObjectId('6758828ca03ea151f330ec9a'), 'ID': 2044184042, 'name': 'HERO[3] Web Filter Suite - A New Way to Protect Your Family', 'category': 'Software', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2015, 12, 16, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 11, 1, 15, 20, 12), 'pledged': 1511.0, 'state': 'failed', 'backers': 14, 'country': 'US', 'usd_pledged': 1511.0, 'usd_pledged_real': 1511.0}
# {'_id': ObjectId('6758828ca03ea151f330ecff'), 'ID': 1153712773, 'name': 'SULTAN OF SCRAPE', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2013, 6, 8, 0, 0), 'goal': 1000000.0, 'launched': datetime.datetime(2013, 5, 9, 9, 32, 52), 'pledged': 365.0, 'state': 'failed', 'backers': 5, 'country': 'US', 'usd_pledged': 365.0, 'usd_pledged_real': 365.0}
# {'_id': ObjectId('6758828ca03ea151f330ed05'), 'ID': 205248352, 'name': 'Unique B&B by preserving historic MCM Jap. Prairie ranch', 'category': 'Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2015, 5, 5, 0, 0), 'goal': 450000.0, 'launched': datetime.datetime(2015, 4, 21, 21, 13, 28), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330ed40'), 'ID': 1912919329, 'name': 'Cancer Cure-The Movie-Big Pharma, Russian Mafia, One Doctor.', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2014, 3, 31, 0, 0), 'goal': 500000.0, 'launched': datetime.datetime(2014, 2, 25, 5, 40, 5), 'pledged': 1.0, 'state': 'canceled', 'backers': 1, 'country': 'US', 'usd_pledged': 1.0, 'usd_pledged_real': 1.0}
# {'_id': ObjectId('6758828ca03ea151f330ed5d'), 'ID': 203543199, 'name': 'The Essence Within Game Project', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2013, 5, 12, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2013, 4, 12, 10, 32, 25), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330ed73'), 'ID': 688189671, 'name': 'Sheep Dogs', 'category': 'Action', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2015, 11, 22, 0, 0), 'goal': 300000.0, 'launched': datetime.datetime(2015, 10, 23, 17, 52, 32), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330edc5'), 'ID': 1057139728, 'name': 'Breathe Easy Infusion Chapmint (Canceled)', 'category': 'Product Design', 'main_category': 'Design', 'currency': 'USD', 'deadline': datetime.datetime(2015, 4, 24, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 2, 23, 20, 31, 43), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330ee3d'), 'ID': 130818133, 'name': 'GIVING', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 3, 11, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2012, 1, 26, 23, 5, 45), 'pledged': 520.0, 'state': 'failed', 'backers': 2, 'country': 'US', 'usd_pledged': 520.0, 'usd_pledged_real': 520.0}
# {'_id': ObjectId('6758828ca03ea151f330ee62'), 'ID': 889238790, 'name': 'BassCase - Bold Sound in an iPhone Case', 'category': 'Sound', 'main_category': 'Technology', 'currency': 'USD', 'deadline': datetime.datetime(2015, 12, 17, 0, 0), 'goal': 350000.0, 'launched': datetime.datetime(2015, 11, 12, 18, 1, 59), 'pledged': 6087.0, 'state': 'failed', 'backers': 68, 'country': 'US', 'usd_pledged': 6087.0, 'usd_pledged_real': 6087.0}
# {'_id': ObjectId('6758828ca03ea151f330ee68'), 'ID': 458933142, 'name': "Back in the 50's again (Canceled)", 'category': 'Restaurants', 'main_category': 'Food', 'currency': 'USD', 'deadline': datetime.datetime(2015, 2, 27, 0, 0), 'goal': 275000.0, 'launched': datetime.datetime(2015, 1, 28, 1, 7, 15), 'pledged': 0.0, 'state': 'canceled', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330ee72'), 'ID': 1901615175, 'name': "D.A.'s dresses, ties, bow ties, blankets, gifts, and cakes!", 'category': 'Accessories', 'main_category': 'Fashion', 'currency': 'USD', 'deadline': datetime.datetime(2015, 12, 25, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2015, 11, 16, 4, 20, 58), 'pledged': 0.0, 'state': 'failed', 'backers': 0, 'country': 'US', 'usd_pledged': 0.0, 'usd_pledged_real': 0.0}
# {'_id': ObjectId('6758828ca03ea151f330ee82'), 'ID': 505377396, 'name': 'ChuSingura46+1 - A Visual Novel with Moe Samurai Girls', 'category': 'Video Games', 'main_category': 'Games', 'currency': 'USD', 'deadline': datetime.datetime(2016, 4, 24, 0, 0), 'goal': 210000.0, 'launched': datetime.datetime(2016, 3, 10, 12, 25, 25), 'pledged': 6285.0, 'state': 'canceled', 'backers': 131, 'country': 'US', 'usd_pledged': 6285.0, 'usd_pledged_real': 6285.0}
# {'_id': ObjectId('6758828ca03ea151f330eed3'), 'ID': 2026697614, 'name': 'Metro County PD', 'category': 'Film & Video', 'main_category': 'Film & Video', 'currency': 'USD', 'deadline': datetime.datetime(2012, 12, 8, 0, 0), 'goal': 250000.0, 'launched': datetime.datetime(2012, 11, 6, 1, 36, 40), 'pledged': 15.0, 'state': 'failed', 'backers': 1, 'country': 'US', 'usd_pledged': 15.0, 'usd_pledged_real': 15.0}

# %% [markdown]
# ## Question 6

# %%
# Compter le nombre de projet ayant "Sport" dans leur nom

count_sport_projects = collection.count_documents({
    'name': {'$regex': 'Sport', '$options': 'i'}  # Recherche insensible à la casse
})

print(f"Nombre de projets ayant 'Sport' dans leur nom : {count_sport_projects}")
# Out:
# Nombre de projets ayant 'Sport' dans leur nom : 500
